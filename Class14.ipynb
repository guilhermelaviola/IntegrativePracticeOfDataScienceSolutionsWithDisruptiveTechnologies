# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/IntegrativePracticeOfDataScienceSolutionsWithDisruptiveTechnologies/blob/main/Class14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dashboard Development with Python**
# Data management and visualization are essential for informed decision-making across various contexts. Key tools in this domain include the Python ecosystem, which provides libraries for effective data handling. Efficient organization of data can be achieved through databases, such as CSV files, commonly used for educational integrations. Interactive dashboards, powered by tools like Plotly and Dash, enable users to visualize trends and insights effectively. Plotly offers simplified syntax for creating complex graphs, while Dash allows web-based application development without deep front-end knowledge. The integration of predictive models using libraries like Scikit-learn adds a forward-looking aspect to data analysis, enhancing training optimizations. Overall, employing Pandas, Plotly, Dash, and Scikit-learn forms a robust pipeline for transforming raw data into actionable insights, modernizing decision-making strategies in various fields.

# %%
# Importing all the necessary libraries and resources:
# !pip install dash pandas plotly scikit-learn
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import pandas as pd
from sklearn.linear_model import LinearRegression
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 54.8 MB/s eta 0:00:00
# ...

# %%
# Generating fictional player data:
data = {
    'Player_Name': ['Lautaro', 'Thuram', 'Barella', 'Çalhanoglu', 'Mkhitaryan', 'Dimarco', 'Dumfries'],
    'Player_Age': [28, 28, 28, 32, 36, 28, 29],
    'Goals': [163, 34, 19, 31, 8, 13, 19],
    'Assists': [33, 38, 27, 38, 23, 32, 34],
    'Nationality': ['Argentina', 'France', 'Italy', 'Turkey', 'Armenia', 'Italy', 'Netherlands']
}

df = pd.DataFrame(data)
print(df)
# Out:
#   Player_Name  Player_Age  Goals  Assists  Nationality
# 0     Lautaro          28    163       33    Argentina
# 1      Thuram          28     34       38       France
# 2     Barella          28     19       27        Italy
# 3  Çalhanoglu          32     31       38       Turkey
# 4  Mkhitaryan          36      8       23      Armenia
# 5     Dimarco          28     13       32        Italy
# 6    Dumfries          29     19       34  Netherlands

# %%
# Simple predictive model (Linear Regression):
X = df[['Goals']]
y = df['Assists']
model = LinearRegression()
model.fit(X, y)

# Adding predictions to the DataFrame:
df['Predicted_Level'] = model.predict(X)

# Initializing the Dash app:
app = dash.Dash(__name__)

# %%
# Dashboard layout
app.layout = html. Div([
    html.H1("Dashboard of the"D,
            dcc.Dropdown(
                id='samurai-dropdown',
options=[{'label': nome, 'value': nome} for nome in df['Name']],
value=df['Nome'][e], # Initial value
clearable=False
            ),
            dcc.Graph(id='prediction-chart'),

# Callback to update the graph
@app.callback(
    Output('prediction-chart', 'figure'),
    Input('player-dropdown', 'value')

def update_figure(selected_samurai):
  df_filtrado = df[df['Name'] == selected_samurai]
               fig = px.bar(df_filtrado, x='Name', y=['Zen_Level', 'Predicted_Zen_Level'],
                            barmode='group',
                            title=f"Actual vs. Predicted Zen Level for {selected_samurai}",
                            labels={'value': 'Zen Level', 'variable': 'Data Type'})
               return fig

# Runs the application
if __name__ == '__main__':
               app.run_server (debug=True)
