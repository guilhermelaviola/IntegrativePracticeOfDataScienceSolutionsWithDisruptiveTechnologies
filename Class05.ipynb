# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/IntegrativePracticeOfDataScienceSolutionsWithDisruptiveTechnologies/blob/main/Class05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Descriptive Analysis**
# Data analysis is vital across various fields, with Python providing powerful libraries like Pandas, Matplotlib, and Seaborn. Pandas facilitates data manipulation through its DataFrame structure, allowing users to import and process data from multiple sources. Data visualization is crucial for uncovering patterns, trends, and outliers, with Matplotlib and Seaborn enabling the creation of diverse plots. Outliers, which can skew statistical outcomes, are identified using techniques like boxplots from Seaborn. Addressing outliers involves methods such as removal or replacement, contingent on the data's context. Effective data analysis combines tools with a deep understanding of the subject matter, fostering better decision-making through clear visualization. Mastery of these techniques is necessary for deriving insights and adapting to the evolving landscape of data analysis.

# %%
# Installing rpy2, which makes it possible to run R on Colab:
# !pip install -q rpy2

# Loading the extension to use R:
# %load_ext rpy2.ipython

# %%
# %%R
# # Loading the packages:
# library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.5.2
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# %%R
# # Creating an array with the amount of ammunition of different types:
# ammunition <- c(10, 5, 20, 15)
#
# # Creating a data frame with sensor data:
# sensor_data <- data.frame(
#     enemy = c('tank', 'infantry', 'drone', 'tank', 'infantry'),
#     distance = c(120, 50, 200, 90, 30),
#     damage = c(0, 15, 5, 10, 20),
#     remaining_ammunition = c(30, 50, 25, 10, 40)
# )

# %%
# %%R
# # Basic operations for data manipulation with dplyr:
# library(dplyr)
#
# filtered_data <- sensor_data %>%
# filter(distance < 100) %>% # Filtering close enemies
# select(enemy, distance, damage) # Selecting only relevant columns

# %%
# %%R
# # Data visualization with ggplot2:
# library(ggplot2)
#
# ggplot(sensor_data, aes(x = enemy, y = damage)) +
# geom_bar(stat = 'identity', fill = 'orange') + # Bar chart
# labs(title = 'Damage caused by enemy type', x = 'Enemy type', y = 'Damage')
